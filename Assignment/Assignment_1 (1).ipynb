# %%
# two variables
a=25
b=3.5
print(a)
print(b)

# string and bool variables
name="haseeba abid"
boolean=True
print(name)
print(boolean)


# operations on numbers
num1=int(input("enter first num"))
num2=int(input("enter second number"))

add=num1+num2
sub=num1-num2
product=num1*num2
div=num1/num2

print("sum is : ",add)
print("minus is :",sub)
print("product is :",product)
print("division is :",div)


# floor division and remainder
number=int(input("enter number"))

result=number//5
remainder=number%5

print(result)
print(remainder)


# expression and statement
a=7+3-2//4 #it is expression
print(2-3*5/2)

name="sara" # it is statement
age=10
print("ali")


# num to int and product
numb=input("enter number: ")
numb=int(numb)

result=numb*10
print(result)


# str joining
first_name="Haseeba"
last_name="Abid"
full_name=first_name + " " + last_name
print(full_name)


# three times word
word= "blackpink "
print(3*word)


# uppercase, title, len
word="Pink VeNom"
print(word.upper())

print(word.title())

print(len(word))
