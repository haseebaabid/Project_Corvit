# %%
# electricity bill
n=int(input("enter units"))
if n<=100:
        print("your electricity bill is", n *5)

elif n<=200:
        print("your electricity bill is",(100*5) + (n-100)*8)

else:
        print("your electricity bill is",(100*5)+ (100*8) + (n-200)*10)





# grade of student
marks=int(input("enter your marks to know grade"))

if marks>=90:
    print("A grade")

elif 89>=marks>=75 :
    print("B grade")

elif 75>=marks>=50 :
    print("C grade")

else:
      print("fail")




# username and password
name=input("enter username: ")
password=int(input("enter your password"))

if name=="haseeba@123" and password==12345:
      print("you are logged in")

elif  name=="haseeba@123" and password!=12345:
      print("Corret username but wrong password")

else:
      print("wrong username and password")





# largest among three numbers
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))

if a>b:
    if a>c:
        print("a is greater than both numbers", a)
    else:
         print("c is greater than both numbers", c)


elif b>a:
    if b>c:
        print("b is greater than both numbers", b)
    else:
         print("c is greater than both numbers", c)

else:
     print("c is greater than both numbers", c)




# numbers from 1 to 10
n=0
while n<10:
    n+=1
    print(n)




# multiplication table
num=int(input("enter number"))

for i in range(1,11):
    table=(f"{num}x{i} = {num*i}")
    print(table)
