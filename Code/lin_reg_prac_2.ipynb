# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

data={
    "X":[100,200,300,400,500,750,1000],
    "Y":[2,  3,  5,   7,  9,   12,  20]
}

df=pd.DataFrame(data)

x=df[["X"]].values
y=df["Y"].values

print(x.shape)
print(df.shape)

model=LinearRegression()
model.fit(x,y)


print("mean is :", model.coef_[0])
print("intercept is: ", model.intercept_)

y_pred=model.predict(x)

plt.scatter(x, y, color="maroon", label="actual values")
plt.plot(x, y_pred, color="pink", label="predicted values")
plt.legend()
plt.show()
# Out:
# (7, 1)
# (7, 2)
# mean is : 0.019337278106508874
# intercept is:  -0.6923076923076898

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

data={
    "X":[100,200,300,400,500,750,1000],
    "Y":[2,  3,  5,   7,  9,   12,  20]
}

df=pd.DataFrame(data)

x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.3)

model=LinearRegression()
model.fit(x_train, y_train)

print("slope is: ")
print(model.coef_[0])
print("intercept is: ")
print(model.intercept_)

y_pred=model.predict(x_test)

print("mean_squred_error: ")
print(mean_squared_error(y_test, y_pred))

print("mean absolute error: ")
print(mean_absolute_error(y_test, y_pred))

plt.scatter(x_test, y_test, color="pink", label="trained values")
plt.scatter(x_train, y_train, color="maroon", label="tested values")
plt.plot(x_test, y_pred, color="teal", label="predicted values")
plt.legend()
plt.show()
# Out:
# slope is:
# 0.020319715808170512
# intercept is:
# -1.4458259325044391
# mean_squred_error:
# 0.7408358546103865
# mean absolute error:
# 0.6939017169923024
